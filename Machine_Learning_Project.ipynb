# %% [markdown]
# <a href="https://colab.research.google.com/github/anhb8/Machine-Learning-Final-Project----Nguyen-Alina/blob/main/Machine_Learning_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-49009ce9-cb76-4e9a-8e27-5af7d783edd3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49009ce9-cb76-4e9a-8e27-5af7d783edd3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving boat_data.csv to boat_data.csv
# ...

# %%
import pandas as pd
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt

df = pd.read_csv('boat_data.csv')
df.dtypes
# Out:
# Price                           object
# Boat Type                       object
# Manufacturer                    object
# Type                            object
# Year Built                       int64
# Length                         float64
# Width                          float64
# Material                        object
# Location                        object
# Number of views last 7 days      int64
# dtype: object

# %%
sns.countplot(y='Material',data=df)

# %%
import matplotlib.pyplot as plt
sns.lineplot(x='Material',y='Number of views last 7 days',data=df)

# %%
sns.regplot(x='Length',y='Width',data=df)
